# %% [markdown]
# # Practice in the first module of Pandas

# %% [markdown]
# ### **1-mashq**. `Pandas` kutubxonasini `pd`, `numpy` kutubxonasini `np` deb chaqirib oling

# %%
# Javobni shuyerga yozing
import pandas as pd
import numpy as np

# %% [markdown]
# ### Mashg'ulot uchun DF yuklab olamiz.
# Quyidagi kodni bajaring

# %%
df = pd.read_csv("usa_cars.csv", index_col=0)

# %% [markdown]
# ### **2-mashq.** DF hajmini chiqaring

# %%
# Javobni shuyerga yozing
df.shape
# Out:
# (2499, 12)

# %% [markdown]
# ### **3-mashq**. DF boshidan 6 ta qator chiqaring

# %%
# Javobni shuyerga yozing
df.head(6)
# Out:
#    price      brand    model  year   title_status  mileage   color  \
# 0   6300     toyota  cruiser  2008  clean vehicle   274117   black
# 1   2899       ford       se  2011  clean vehicle   190552  silver
# 2   5350      dodge      mpv  2018  clean vehicle    39590  silver
# 3  25000       ford     door  2014  clean vehicle    64146    blue
# 4  27700  chevrolet     1500  2018  clean vehicle     6654     red
# 5   5700      dodge      mpv  2018  clean vehicle    45561   white
#
#                    vin        lot       state country      condition
# 0    jtezu11f88k007763  159348797  new jersey     usa   10 days left
# 1    2fmdk3gc4bbb02217  166951262   tennessee     usa    6 days left
# 2    3c4pdcgg5jt346413  167655728     georgia     usa    2 days left
# 3    1ftfw1et4efc23745  167753855    virginia     usa  22 hours left
# 4    3gcpcrec2jg473991  167763266     florida     usa  22 hours left
# 5    2c4rdgeg9jr237989  167655771       texas     usa    2 days left

# %% [markdown]
# ### **4-mashq.** DF oxiridan 5 ta qator chiqaring

# %%
# Javobni shuyerga yozing
df.tail(5)
# Out:
#       price   brand  model  year   title_status  mileage   color  \
# 2494   7800  nissan  versa  2019  clean vehicle    23609     red
# 2495   9200  nissan  versa  2018  clean vehicle    34553  silver
# 2496   9200  nissan  versa  2018  clean vehicle    31594  silver
# 2497   9200  nissan  versa  2018  clean vehicle    32557   black
# 2498   9200  nissan  versa  2018  clean vehicle    31371  silver
#
#                       vin        lot       state country      condition
# 2494    3n1cn7ap9kl880319  167722715  california     usa    1 days left
# 2495    3n1cn7ap5jl884088  167762225     florida     usa  21 hours left
# 2496    3n1cn7ap9jl884191  167762226     florida     usa  21 hours left
# 2497    3n1cn7ap3jl883263  167762227     florida     usa    2 days left
# 2498    3n1cn7ap4jl884311  167762228     florida     usa  21 hours left

# %% [markdown]
# ### **5-mashq**. DF ni yili `year` bo'yicha tartiblab chiqaring

# %%
# Javobni shuyerga yozing
df.sort_values(by = 'year', ascending = False)
# Out:
#       price      brand    model  year       title_status  mileage       color  \
# 2339  19800     nissan    rogue  2020      clean vehicle    14850      silver
# 399   61200        bmw   series  2020      clean vehicle     7509       black
# 2305  14700     nissan    rogue  2020      clean vehicle    15387        gray
# 2302  21100     nissan    rogue  2020      clean vehicle    19597      silver
# 1704  25200       ford   escape  2020      clean vehicle        7       black
# ...     ...        ...      ...   ...                ...      ...         ...
# 362      25       ford   pickup  1994  salvage insurance   206162       white
# 322       0       ford  chassis  1994  salvage insurance        0       green
# 545       0        gmc     door  1993  salvage insurance        0  light blue
# 405      25       ford     door  1984  salvage insurance    41577       white
# 32    29800  chevrolet   camaro  1973      clean vehicle    46226         red
#
#                       vin        lot           state country      condition
# 2339    knmat2mv2lp511637  167614830       minnesota     usa  14 hours left
# 399     wba7t2c04lgl17687  167417053      california     usa    7 days left
# 2305    knmat2mv5lp500471  167743353    pennsylvania     usa    2 days left
# 2302    5n1at2mt6lc714032  167725016  south carolina     usa  21 hours left
# 1704    1fmcu9f61lua48374  167751305        virginia     usa  21 hours left
# ...                   ...        ...             ...     ...            ...
# 362     1ftdf15y2rnb12612  167361489         georgia     usa    2 days left
# 322     1fdee14n7rha47894  167359174      california     usa  19 hours left
# 545     1gkfk16k5pj701631  167358601        colorado     usa  18 hours left
# 405     2ftcf15y9eca14589  167611661        arkansas     usa  17 hours left
# 32          1q87t3n166389  167763370    pennsylvania     usa  22 hours left
#
# [2499 rows x 12 columns]

# %% [markdown]
# ### **6-mashq**. DF qatorlarini narxi bo'yicha reytinglang va konsolga narxi bo'yicha tartiblangan holatda chiqaring.

# %%
# Javobni shuyerga yozing
df.sort_values(by = "price", ascending = True)
# Out:
#       price          brand       model  year       title_status  mileage  \
# 410       0      chevrolet        door  1995  salvage insurance   274706
# 330       0           ford        door  1996  salvage insurance   296860
# 331       0           ford        door  2006  salvage insurance   203158
# 339       0           ford        door  2002  salvage insurance   214800
# 496       0           ford      pickup  1996  salvage insurance   252588
# ...     ...            ...         ...   ...                ...      ...
# 1215  65500           ford         srw  2019      clean vehicle     6500
# 277   67000          dodge  challenger  2019      clean vehicle    10944
# 1336  70000           ford         drw  2019      clean vehicle     9643
# 1340  74000           ford         drw  2019      clean vehicle    10536
# 502   84900  mercedes-benz    sl-class  2017      clean vehicle    25302
#
#          color                  vin        lot           state country  \
# 410      green    2gcec19h8s1195266  167425634         arizona     usa
# 330      green    1falp62w5th144314  167359712      california     usa
# 331        red    1fmzk04136ga07119  167610991        illinois     usa
# 339      black    3fafp37372r151014  167360232  south carolina     usa
# 496        red    1ftef15n0tlc14455  167357804        oklahoma     usa
# ...        ...                  ...        ...             ...     ...
# 1215     black    1ft7w2bt0kec44818  167718954         indiana     usa
# 277       blue    2c3cdzl97kh518237  167759490            ohio     usa
# 1336  no_color    1ft8w3dt3kee48276  167780680        illinois     usa
# 1340  no_color    1ft8w4dt6ked32656  167780682        illinois     usa
# 502     silver    wddjk7ea3hf044968  167607883         florida     usa
#
#           condition
# 410     2 days left
# 330   19 hours left
# 331   17 hours left
# 339     2 days left
# 496   17 hours left
# ...             ...
# 1215  21 hours left
# 277   21 hours left
# 1336    2 days left
# 1340    2 days left
# 502     2 days left
#
# [2499 rows x 12 columns]

# %% [markdown]
# ### **7-mashq**. DFdan eng qimmat mashina haqidagi ma'lumotni chiqaring

# %%
# Javobni shuyerga yozing
df.iloc[df["price"].argmax()]
# Out:
# price                         84900
# brand                 mercedes-benz
# model                      sl-class
# year                           2017
# title_status          clean vehicle
# mileage                       25302
# color                        silver
# vin               wddjk7ea3hf044968
# lot                       167607883
# state                       florida
# country                         usa
# condition               2 days left
# Name: 502, dtype: object

# %% [markdown]
# ### **8-mashq**. DFdan eng ko'p yurgan (`km_driven`) mashina haqidagi ma'lumotni chiqaring

# %%
# Javobni shuyerga yozing
df.iloc[df["mileage"].argmax()]
# Out:
# price                          1025
# brand                     peterbilt
# model                         truck
# year                           2010
# title_status      salvage insurance
# mileage                     1017936
# color                        color:
# vin               1xp7d49x0ad793710
# lot                       167529842
# state                       georgia
# country                         usa
# condition             17 hours left
# Name: 528, dtype: object

# %% [markdown]
# ### **9-mashq**. DF dagi barcha brandlar va ularning sonini chiqaring

# %%
# Javobni shuyerga yozing
df["brand"].value_counts()
# Out:
# brand
# ford               1235
# dodge               432
# nissan              312
# chevrolet           297
# gmc                  42
# jeep                 30
# chrysler             18
# bmw                  17
# hyundai              15
# kia                  13
# buick                13
# infiniti             12
# honda                12
# cadillac             10
# mercedes-benz        10
# heartland             5
# land                  4
# peterbilt             4
# audi                  4
# acura                 3
# lincoln               2
# lexus                 2
# mazda                 2
# maserati              1
# toyota                1
# harley-davidson       1
# jaguar                1
# ram                   1
# Name: count, dtype: int64

# %% [markdown]
# ### **10-mashq**. DF dagi raqamli ustunlar haqida umulashtiruvchi statistikani chiqaring (min, max, mean, std va hokazo)

# %%
# Javobni shuyerga yozing
df.describe()
# Out:
#               price         year       mileage           lot
# count   2499.000000  2499.000000  2.499000e+03  2.499000e+03
# mean   18767.671469  2016.714286  5.229869e+04  1.676914e+08
# std    12116.094936     3.442656  5.970552e+04  2.038772e+05
# min        0.000000  1973.000000  0.000000e+00  1.593488e+08
# 25%    10200.000000  2016.000000  2.146650e+04  1.676253e+08
# 50%    16900.000000  2018.000000  3.536500e+04  1.677451e+08
# 75%    25555.500000  2019.000000  6.347250e+04  1.677798e+08
# max    84900.000000  2020.000000  1.017936e+06  1.678055e+08

# %% [markdown]
# ### **11-mashq**. DF dan ford kompaniyasining barcha mashinalarnini ajratib chiqaring

# %%
# Javobni shuyerga yozing
df[df["brand"] == 'ford']
# Out:
#       price brand   model  year   title_status  mileage     color  \
# 1      2899  ford      se  2011  clean vehicle   190552    silver
# 3     25000  ford    door  2014  clean vehicle    64146      blue
# 9      5250  ford     mpv  2017  clean vehicle    63418     black
# 14    20700  ford    door  2013  clean vehicle   100757     black
# 18     5210  ford     mpv  2017  clean vehicle    35714     white
# ...     ...   ...     ...   ...            ...      ...       ...
# 2199  13800  ford  fusion  2019  clean vehicle    29345     white
# 2200  56000  ford     srw  2018  clean vehicle    25371     black
# 2201  13800  ford  fusion  2019  clean vehicle    30054    silver
# 2202  45800  ford     srw  2018  clean vehicle    11173     white
# 2203  13800  ford  fusion  2019  clean vehicle    30902  no_color
#
#                       vin        lot           state country      condition
# 1       2fmdk3gc4bbb02217  166951262       tennessee     usa    6 days left
# 3       1ftfw1et4efc23745  167753855        virginia     usa  22 hours left
# 9       2fmpk3j92hbc12542  167656121           texas     usa    2 days left
# 14      1ftfw1et7dfa47790  167753916        virginia     usa  22 hours left
# 18      2fmpk3j95hbb73607  167656124           texas     usa    2 days left
# ...                   ...        ...             ...     ...            ...
# 2199    3fa6p0lu1kr222799  167802379  north carolina     usa    2 days left
# 2200    1ft7w2bt4jec50359  167749689    pennsylvania     usa    3 days left
# 2201    3fa6p0lu3kr210749  167802380  north carolina     usa    2 days left
# 2202    1ft7w2bt3jeb02932  167749690    pennsylvania     usa    2 days left
# 2203    3fa6p0lu8kr225585  167802381  north carolina     usa    2 days left
#
# [1235 rows x 12 columns]

# %% [markdown]
# ### **12-mashq**. Nissan kompaniyasining eng qimmat va eng arzon mashinalarini chiqaring

# %%
# Javobni shuyerga yozing
nissan_df = df[df["brand"] == "nissan"]
nissan_df.iloc[nissan_df['price'].argmax()]
# Out:
# price                         36300
# brand                        nissan
# model                            xd
# year                           2017
# title_status          clean vehicle
# mileage                       16224
# color                         white
# vin               1n6ba1f46hn535299
# lot                       167753308
# state                      virginia
# country                         usa
# condition             21 hours left
# Name: 2375, dtype: object

# %%
nissan_df.iloc[nissan_df['price'].argmin()]
# Out:
# price                           375
# brand                        nissan
# model                          door
# year                           2017
# title_status      salvage insurance
# mileage                           1
# color                           red
# vin               3n1ce2cp0hl360793
# lot                       167619908
# state                north carolina
# country                         usa
# condition               2 days left
# Name: 2417, dtype: object

# %% [markdown]
# ### **13-mashq**. Chevrolet kompaniyasining barcha modellarini chiqaring

# %%
# Javobni shuyerga yozing
df[df["brand"] == "chevrolet"]
# Out:
#      price      brand     model  year   title_status  mileage   color  \
# 4    27700  chevrolet      1500  2018  clean vehicle     6654     red
# 6     7300  chevrolet        pk  2010  clean vehicle   149050   black
# 8    14600  chevrolet    malibu  2018  clean vehicle     9371  silver
# 12   31900  chevrolet      1500  2018  clean vehicle    22909   black
# 22   15000  chevrolet      door  2015  clean vehicle    61578   black
# ..     ...        ...       ...   ...            ...      ...     ...
# 803  28300  chevrolet        ld  2019  clean vehicle    27665     red
# 804  27300  chevrolet        ld  2019  clean vehicle    25427   black
# 805   3500  chevrolet      door  2013  clean vehicle    78198    gray
# 806  28300  chevrolet  colorado  2020  clean vehicle    13886  silver
# 807  18300  chevrolet    impala  2019  clean vehicle    34538  silver
#
#                      vin        lot       state country      condition
# 4      3gcpcrec2jg473991  167763266     florida     usa  22 hours left
# 6      1gcsksea1az121133  167753872     georgia     usa  22 hours left
# 8      1g1zd5st5jf191860  167763267     florida     usa  22 hours left
# 12     3gcukrec0jg176059  167763273   tennessee     usa  22 hours left
# 22     2gnflhe33f6214023  167763280        ohio     usa    2 days left
# ..                   ...        ...         ...     ...            ...
# 803    2gcvkpec1k1124569  167805479     indiana     usa    2 days left
# 804    2gcvkpec4k1105269  167805483     indiana     usa    2 days left
# 805    1g11c5saxdf350889  167617243  new jersey     usa    7 days left
# 806    1gcgtcen7l1101496  167805497     indiana     usa    2 days left
# 807    2g11z5s37k9134455  167805500     indiana     usa    2 days left
#
# [297 rows x 12 columns]

# %% [markdown]
# ### **14-mashq**. Mashina narxi va yili o'rtasidagi korrelyasiya qiymatini chiqaring

# %%
# Javobni shuyerga yozing
df[['price', 'year']].corr()
# Out:
#           price      year
# price  1.000000  0.418274
# year   0.418274  1.000000

# %% [markdown]
# ### **14-mashq**. Mashina narxi va boshqa ustunlar o'rtasidagi korrelyasiyani chiqaring

# %%
df[['price',]].corr()
# Out:
#        price
# price    1.0

# %% [markdown]
# ### **15-mashq**. DF dan kia va hyundai mashinalarini ajratib alohida DF ga saqlang. Yangi DFni chiqaring

# %%
# Javobni shuyerga yozing
new_df = df[(df["brand"] == "kia") | (df["brand"] == "hyundai")]
new_df
# Out:
#      price    brand     model  year       title_status  mileage  \
# 16    5200      kia     forte  2018      clean vehicle    46194
# 21    7300      kia     forte  2018      clean vehicle    38823
# 26   21500      kia   sorento  2020      clean vehicle    11451
# 287   8200  hyundai      door  2017      clean vehicle    56690
# 288   3000      kia      door  2013      clean vehicle    97142
# 291  12700      kia      soul  2019      clean vehicle    23514
# 292  13800      kia   sorento  2017      clean vehicle    86959
# 296   9800  hyundai   elantra  2017      clean vehicle    35687
# 366   5350  hyundai       mpv  2019      clean vehicle    43536
# 389   3760  hyundai     doors  2019      clean vehicle    30382
# 417   5998  hyundai     doors  2014      clean vehicle   122975
# 419      0      kia     wagon  2008  salvage insurance   148463
# 424   3960  hyundai     doors  2019      clean vehicle    35623
# 438   4010  hyundai     doors  2019      clean vehicle    31233
# 440  13000      kia  sportage  2017      clean vehicle    71991
# 450   4690  hyundai       mpv  2019      clean vehicle    33785
# 463   8000  hyundai      door  2015      clean vehicle    88274
# 486   4730  hyundai       mpv  2019      clean vehicle    30121
# 513   4650  hyundai       mpv  2019      clean vehicle    27492
# 525   3440  hyundai     doors  2019      clean vehicle    34895
# 527   3810      kia      door  2016      clean vehicle    39408
# 537   4750  hyundai       mpv  2019      clean vehicle    25847
# 549   3460  hyundai      door  2012      clean vehicle   142106
# 551   3250  hyundai      door  2015      clean vehicle   111612
# 623  14000      kia   sorento  2017      clean vehicle    53424
# 626  13300      kia      door  2017      clean vehicle    37125
# 629  15500      kia   sorento  2017      clean vehicle    37668
# 631  21500      kia   sorento  2017      clean vehicle    43761
#
#              color                  vin        lot           state country  \
# 16            blue    3kpfk4a77je198723  167801757  north carolina     usa
# 21           black    3kpfl4a79je272611  167801773  north carolina     usa
# 26            blue    5xypg4a59lg616029  167801828  north carolina     usa
# 287          white    5npd84lf6hh128808  167117726     connecticut     usa
# 288         silver    knagm4a75d5378293  167552545        missouri     usa
# 291         silver    kndjp3a55k7006351  167679072      california     usa
# 292           gray    5xyphda50hg232046  167803771  north carolina     usa
# 296            red    kmhd84lf5hu191402  167117732     connecticut     usa
# 366           blue    km8j33a49ku860727  167698680         florida     usa
# 389         silver    5npd84lf6kh456317  167698685         florida     usa
# 417  phantom black    5npdh4ae0eh480157  167279690        new york     usa
# 419         silver    knafg525787197602  167247592         indiana     usa
# 424            red    5npd84lf5kh403222  167697946            ohio     usa
# 438         silver    kmhd84lf4ku746279  167697947            ohio     usa
# 440         silver    kndpn3ac7h7113313  167606881      new jersey     usa
# 450         silver    km8k12aa0ku242609  167697948            ohio     usa
# 463            red    km8jucag9fu984199  167607388    pennsylvania     usa
# 486            red    km8j23a45ku893842  167697951            ohio     usa
# 513          white    km8j23a44ku882752  167697953            ohio     usa
# 525           gray    3kpc24a34ke050725  167697954            ohio     usa
# 527          black    kndjx3ae3g7012477  167692796      california     usa
# 537           gray    km8j23a4xku846404  167697955            ohio     usa
# 549          white    5npeb4ac2ch437716  167697983     mississippi     usa
# 551           gray    5npdh4ae3fh644096  167692885      california     usa
# 623          black    5xypgda51hg221253  167119104     connecticut     usa
# 626       no_color    5xypgda39hg262132  167119105     connecticut     usa
# 629            red    5xypgda59hg292944  167119106     connecticut     usa
# 631           gray    5xypkda50hg299327  167119107     connecticut     usa
#
#          condition
# 16     2 days left
# 21     2 days left
# 26     2 days left
# 287   5 hours left
# 288    9 days left
# 291   10 days left
# 292    3 days left
# 296   5 hours left
# 366  22 hours left
# 389  22 hours left
# 417    5 days left
# 419  16 hours left
# 424    2 days left
# 438    2 days left
# 440   2 hours left
# 450    2 days left
# 463    7 days left
# 486    2 days left
# 513    2 days left
# 525    2 days left
# 527  20 hours left
# 537    2 days left
# 549    2 days left
# 551  20 hours left
# 623   5 hours left
# 626   5 hours left
# 629   5 hours left
# 631   5 hours left

# %% [markdown]
# ### **16-mashq**. Chevrolet kompaniyasining malibu va impala mashinalarini alohida DF ko'rinishida chiqaring

# %%
# Javobni shuyerga yozing
chev = df[df['brand'] == 'chevrolet']
chev[(chev['model'] == 'malibu') | (chev['model'] == 'impala')]
# Out:
#      price      brand   model  year   title_status  mileage     color  \
# 8    14600  chevrolet  malibu  2018  clean vehicle     9371    silver
# 47   19000  chevrolet  malibu  2017  clean vehicle    18414     white
# 107  18003  chevrolet  malibu  2017  clean vehicle    19117  no_color
# 204   6000  chevrolet  malibu  2018  clean vehicle    42090      gray
# 266  17100  chevrolet  malibu  2019  clean vehicle    15780     white
# 278  18900  chevrolet  impala  2019  clean vehicle    27601     white
# 281  18300  chevrolet  impala  2019  clean vehicle    25809     black
# 569  13500  chevrolet  impala  2018  clean vehicle    53194     white
# 647   9000  chevrolet  malibu  2016  clean vehicle    67527      gray
# 677  13700  chevrolet  malibu  2019  clean vehicle    47282    silver
# 686  12300  chevrolet  malibu  2018  clean vehicle    53599     black
# 688  13600  chevrolet  malibu  2018  clean vehicle    36047     white
# 691  13000  chevrolet  malibu  2018  clean vehicle    41751      gray
# 731  25000  chevrolet  impala  2020  clean vehicle    18715    silver
# 740  13700  chevrolet  impala  2019  clean vehicle    14939      blue
# 741  15900  chevrolet  malibu  2019  clean vehicle    22026     black
# 768  10200  chevrolet  malibu  2018  clean vehicle    45836     white
# 791  15200  chevrolet  impala  2019  clean vehicle    32248       red
# 792  15000  chevrolet  impala  2019  clean vehicle    36165    silver
# 793  15500  chevrolet  impala  2019  clean vehicle    29922  charcoal
# 794  15700  chevrolet  impala  2019  clean vehicle    26848    silver
# 795  14800  chevrolet  impala  2019  clean vehicle    41163  charcoal
# 797   8200  chevrolet  impala  2017  clean vehicle   100315     black
# 807  18300  chevrolet  impala  2019  clean vehicle    34538    silver
#
#                      vin        lot           state country      condition
# 8      1g1zd5st5jf191860  167763267         florida     usa  22 hours left
# 47     1g1zh5sx9hf118136  167763675       tennessee     usa  22 hours left
# 107    1g1zh5sx7hf141060  167765112        michigan     usa  17 hours left
# 204    1g1zb5st8jf226848  167765944           texas     usa  21 hours left
# 266    1g1zd5st5kf112138  167767034      washington     usa    2 days left
# 278    1g11z5s37ku129047  167767312           texas     usa  21 hours left
# 281    2g11z5s33k9132248  167767315           texas     usa  21 hours left
# 569    2g1105s3xj9121918  167773137      new jersey     usa   7 hours left
# 647    1g1zj5su8gf337274  167780142       wisconsin     usa  21 hours left
# 677    1g1zd5st4kf126371  167787112        oklahoma     usa  21 hours left
# 686    1g1zd5stxjf140841  167787955        oklahoma     usa  21 hours left
# 688    1g1zd5st5jf249837  167787964        oklahoma     usa  21 hours left
# 691    1g1zd5st8jf242655  167787968        oklahoma     usa  21 hours left
# 731    1g1105s31lu100901  167796081          nevada     usa   6 hours left
# 740    2g11z5s30k9137729  167796203          nevada     usa      9 minutes
# 741    1g1zd5st0kf187281  167796205          nevada     usa   1 hours left
# 768    1g1zd5stxjf175198  167800168           texas     usa    2 days left
# 791    1g11z5sa4ku113760  167801930  north carolina     usa    2 days left
# 792    1g11z5sa7ku117222  167801932  north carolina     usa    2 days left
# 793    2g11z5saxk9120208  167801934  north carolina     usa    2 days left
# 794    2g11z5sa5k9140950  167801935  north carolina     usa    2 days left
# 795    2g11z5sa8k9139310  167801936  north carolina     usa    2 days left
# 797    1g1105sa9hu160835  167802211  north carolina     usa    2 days left
# 807    2g11z5s37k9134455  167805500         indiana     usa    2 days left

# %% [markdown]
# ### **17-mashq**. Ford kompaniyasining mustang modelini alohioda DF ga ajrating

# %%
ford = df[df['model'] == 'mustang']
ford
# Out:
#       price brand    model  year   title_status  mileage     color  \
# 632   25511  ford  mustang  2019  clean vehicle    11342      gray
# 1224  21900  ford  mustang  2018  clean vehicle    29748       red
# 1266  22000  ford  mustang  2018  clean vehicle     6248       red
# 1267  38200  ford  mustang  2019  clean vehicle      878     green
# 1269  35000  ford  mustang  2018  clean vehicle     2042      blue
# 1298  49000  ford  mustang  2017  clean vehicle     2205     black
# 1314  21600  ford  mustang  2019  clean vehicle    29457      gray
# 1316  21500  ford  mustang  2019  clean vehicle    29096       red
# 1352  35100  ford  mustang  2019  clean vehicle    10099       red
# 1354  34100  ford  mustang  2019  clean vehicle    10483     white
# 1356  34100  ford  mustang  2019  clean vehicle    10167       red
# 1376  21800  ford  mustang  2018  clean vehicle    16079  no_color
# 1377  18800  ford  mustang  2018  clean vehicle    41147     white
# 1382  19100  ford  mustang  2018  clean vehicle    30594    silver
# 1468  22000  ford  mustang  2018  clean vehicle    39477      gray
# 1640  27000  ford  mustang  2020  clean vehicle    12748       red
# 1695  27900  ford  mustang  2019  clean vehicle    13558     white
# 1749  19600  ford  mustang  2019  clean vehicle    33324      gray
# 1751  27300  ford  mustang  2019  clean vehicle    31260      blue
# 1762  31600  ford  mustang  2019  clean vehicle    16293     black
# 1773  17100  ford  mustang  2018  clean vehicle    31561    silver
# 1913  29800  ford  mustang  2016  clean vehicle    18367      blue
# 1949  20600  ford  mustang  2019  clean vehicle    33965      gray
# 1960  17200  ford  mustang  2018  clean vehicle    32415     white
# 1970  17200  ford  mustang  2018  clean vehicle    32938     white
# 1973  29400  ford  mustang  2019  clean vehicle    25011     white
# 1983  20500  ford  mustang  2019  clean vehicle    35930     black
# 2068  15500  ford  mustang  2019  clean vehicle    25810       red
# 2128  29000  ford  mustang  2019  clean vehicle    12764     black
#
#                       vin        lot        state country      condition
# 632     1fatp8uh4k5177265  167763745     michigan     usa  19 hours left
# 1224    1fatp8uh4j5166362  167773235   new jersey     usa    2 days left
# 1266    1fa6p8th3j5135439  167778967     illinois     usa    2 days left
# 1267    1fa6p8k02k5503784  167732976      florida     usa    1 days left
# 1269    1fa6p8cf9j5131958  167778969     illinois     usa  21 hours left
# 1298    1fa6p8jz8h5523692  167779872     illinois     usa    2 days left
# 1314    1fatp8uh6k5153386  167735493     virginia     usa    2 days left
# 1316    1fatp8uh3k5162367  167735497     virginia     usa    2 days left
# 1352    1fatp8ff1k5110151  167740416  mississippi     usa  21 hours left
# 1354    1fatp8ff5k5106670  167740622  mississippi     usa  21 hours left
# 1356    1fatp8ff0k5119522  167740627  mississippi     usa  21 hours left
# 1376    1fa6p8th0j5176725  167782357   california     usa  21 hours left
# 1377    1fa6p8th1j5133883  167782359   california     usa    2 days left
# 1382    1fatp8uh2j5109805  167782375   california     usa    2 days left
# 1468    1fatp8ff8j5181457  167786970        texas     usa    5 days left
# 1640    1fatp8uh3l5101487  167569997     virginia     usa    2 days left
# 1695    1fa6p8cf9k5108973  167750818   new mexico     usa  21 hours left
# 1749    1fatp8uh2k5158763  167796852       nevada     usa    2 days left
# 1751    1fatp8ff1k5179289  167796914       nevada     usa    2 days left
# 1762    1fa6p8cf1k5144124  167752777      georgia     usa  21 hours left
# 1773    1fatp8uhxj5166415  167798152       nevada     usa    2 days left
# 1913    1fa6p8cf3g5242238  167738456     illinois     usa  21 hours left
# 1949    1fatp8uhxk5148658  167801788      florida     usa    2 days left
# 1960    1fatp8uh2j5132629  167555176   california     usa    8 days left
# 1970    1fatp8uh9j5132644  167555184   california     usa    8 days left
# 1973    1fatp8ff0k5161477  167801794      florida     usa    2 days left
# 1983    1fatp8uh8k5109583  167801796      florida     usa    2 days left
# 2068    1fatp8uhxk5148949  167625718     illinois     usa  19 hours left
# 2128    1fa6p8cf3k5102120  167638863        texas     usa   10 days left

# %% [markdown]
# ### **18-mashq**. 2018-yildan keyin chiqqan Mustang mashinalirining o'rtacha narxini chiqaring

# %%
# Javobni shuyerga yozing
mus = df[df['model'] == 'mustang']
mus[mus['year'] >= 2018]['price'].mean()
# Out:
# np.float64(24837.444444444445)

# %% [markdown]
# ### **19-mashq**. Mustang mashinalari haqida umumlashgan statistikani chiqaring

# %%
# Javobni shuyerga yozing
ford = df[df["brand"] == "ford"]
ford.describe()
# Out:
#               price         year        mileage           lot
# count   1235.000000  1235.000000    1235.000000  1.235000e+03
# mean   21666.888259  2016.762753   52084.304453  1.677053e+08
# std    12945.547175     3.310937   54948.494063  9.829058e+04
# min        0.000000  1984.000000       0.000000  1.669513e+08
# 25%    12530.000000  2016.000000   18878.500000  1.676413e+08
# 50%    22000.000000  2018.000000   34277.000000  1.677452e+08
# 75%    28500.000000  2019.000000   68542.000000  1.677805e+08
# max    74000.000000  2020.000000  999999.000000  1.678024e+08

# %% [markdown]
# ### **20-mashq**. Sotuvdagi ford mashinalarining aksari nechachni yilda ishlab chiqarilganini toping

# %%
# Javobni shuyerga yozing
ford['price'].value_counts()
# Out:
# price
# 0        18
# 28500    12
# 23500    12
# 13800    12
# 26000    12
#          ..
# 65500     1
# 9900      1
# 13799     1
# 30977     1
# 45800     1
# Name: count, Length: 560, dtype: int64
